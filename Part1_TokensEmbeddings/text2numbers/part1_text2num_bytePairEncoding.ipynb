# %% [markdown]
# |<h2>Course:</h2>|<h1><a href="https://udemy.com/course/dullms_x/?couponCode=202508" target="_blank">A deep understanding of AI language model mechanisms</a></h1>|
# |-|:-:|
# |<h2>Part 1:</h2>|<h1>Tokenizations and embeddingss<h1>|
# |<h2>Section:</h2>|<h1>Words to tokens to numbers<h1>|
# |<h2>Lecture:</h2>|<h1><b>Byte-pair encoding<b></h1>|
#
# <br>
#
# <h5><b>Teacher:</b> Mike X Cohen, <a href="https://sincxpress.com" target="_blank">sincxpress.com</a></h5>
# <h5><b>Course URL:</b> <a href="https://udemy.com/course/dullms_x/?couponCode=202508" target="_blank">udemy.com/course/dullms_x/?couponCode=202508</a></h5>
# <i>Using the code without the course may lead to confusion or errors.</i>

# %%
import numpy as np

# %% [markdown]
# # Initialize the vocabulary

# %%
# some text with lots of repetitions
text = 'like liker love lovely hug hugs hugging hearts'

chars = list(set(text))
chars.sort() # initial vocab is sorted

for l in chars:
  print(f'"{l}" appears {text.count(l)} times.')
# Out:
# " " appears 7 times.
# "a" appears 1 times.
# "e" appears 5 times.
# "g" appears 5 times.
# "h" appears 4 times.
# "i" appears 3 times.
# "k" appears 2 times.
# "l" appears 5 times.
# "n" appears 1 times.
# "o" appears 2 times.
# "r" appears 2 times.
# "s" appears 2 times.
# "t" appears 1 times.
# "u" appears 3 times.
# "v" appears 2 times.
# "y" appears 1 times.

# %%
# make a vocabulary
vocab = { word:i for i,word in enumerate(chars) }
vocab
# Out:
# {' ': 0,
#  'a': 1,
#  'e': 2,
#  'g': 3,
#  'h': 4,
#  'i': 5,
#  'k': 6,
#  'l': 7,
#  'n': 8,
#  'o': 9,
#  'r': 10,
#  's': 11,
#  't': 12,
#  'u': 13,
#  'v': 14,
#  'y': 15}

# %%
# the text needs to be a list, not a string
# each element in the list is a token
origtext = list(text)
print(text)
print(origtext)
# Out:
# like liker love lovely hug hugs hugging hearts
# ['l', 'i', 'k', 'e', ' ', 'l', 'i', 'k', 'e', 'r', ' ', 'l', 'o', 'v', 'e', ' ', 'l', 'o', 'v', 'e', 'l', 'y', ' ', 'h', 'u', 'g', ' ', 'h', 'u', 'g', 's', ' ', 'h', 'u', 'g', 'g', 'i', 'n', 'g', ' ', 'h', 'e', 'a', 'r', 't', 's']

# %% [markdown]
# # Find character pairs and merge the most frequent

# %%
token_pairs = dict()

# loop over tokens
for i in range(len(origtext)-1):

  # create a pair
  pair = origtext[i] + origtext[i+1]

  # increase pair frequencies
  if pair in token_pairs:
    token_pairs[pair] += 1
  else:
    token_pairs[pair] = 1

token_pairs
# Out:
# {'li': 2,
#  'ik': 2,
#  'ke': 2,
#  'e ': 2,
#  ' l': 3,
#  'er': 1,
#  'r ': 1,
#  'lo': 2,
#  'ov': 2,
#  've': 2,
#  'el': 1,
#  'ly': 1,
#  'y ': 1,
#  ' h': 4,
#  'hu': 3,
#  'ug': 3,
#  'g ': 2,
#  'gs': 1,
#  's ': 1,
#  'gg': 1,
#  'gi': 1,
#  'in': 1,
#  'ng': 1,
#  'he': 1,
#  'ea': 1,
#  'ar': 1,
#  'rt': 1,
#  'ts': 1}

# %%
# find the most frequent pair
mostFreqPair_idx = np.argmax(list(token_pairs.values()))
mostFreqPair_char = list(token_pairs.keys())[mostFreqPair_idx]
print(f'The most frequent character pair is "{mostFreqPair_char}" with {list(token_pairs.values())[mostFreqPair_idx]} appearances')
# Out:
# The most frequent character pair is " h" with 4 appearances

# %%
# update the vocab
vocab[mostFreqPair_char] = max(vocab.values())+1
vocab
# Out:
# {' ': 0,
#  'a': 1,
#  'e': 2,
#  'g': 3,
#  'h': 4,
#  'i': 5,
#  'k': 6,
#  'l': 7,
#  'n': 8,
#  'o': 9,
#  'r': 10,
#  's': 11,
#  't': 12,
#  'u': 13,
#  'v': 14,
#  'y': 15,
#  ' h': 16}

# %% [markdown]
# # Replace the token pair with one token

# %%
# initialize a new text list
newtext = []

# loop through the list
i = 0
while i<(len(origtext)-1):

  # test whether the pair of this and the following elements match the newly-created pair
  if (origtext[i]+origtext[i+1]) == mostFreqPair_char:

    # append to the new version of the text
    newtext.append(mostFreqPair_char)
    print(f'added "{mostFreqPair_char}"')

    # skip the next character
    i += 2

  # this isn't a merged pair, so add this token to the list
  else:
    newtext.append(origtext[i])

    # move to the next character
    i += 1


  # add the final token to the list (missing in the video)
  if i == (len(origtext)-1):
    newtext.append(origtext[i])



print('\n')
print(f'Original text: {origtext}')
print(f'Updated text:  {newtext}')

print(f'\n\nOriginal text had {len(origtext)} tokens; new text has {len(newtext)} tokens.')
# Out:
# added " h"
# added " h"
# added " h"
# added " h"
#
#
# Original text: ['l', 'i', 'k', 'e', ' ', 'l', 'i', 'k', 'e', 'r', ' ', 'l', 'o', 'v', 'e', ' ', 'l', 'o', 'v', 'e', 'l', 'y', ' ', 'h', 'u', 'g', ' ', 'h', 'u', 'g', 's', ' ', 'h', 'u', 'g', 'g', 'i', 'n', 'g', ' ', 'h', 'e', 'a', 'r', 't', 's']
# Updated text:  ['l', 'i', 'k', 'e', ' ', 'l', 'i', 'k', 'e', 'r', ' ', 'l', 'o', 'v', 'e', ' ', 'l', 'o', 'v', 'e', 'l', 'y', ' h', 'u', 'g', ' h', 'u', 'g', 's', ' h', 'u', 'g', 'g', 'i', 'n', 'g', ' h', 'e', 'a', 'r', 't', 's']
#
#
# Original text had 46 tokens; new text has 42 tokens.

# %% [markdown]
# # Find the most common letter pairs (again!)

# %%
token_pairs = dict()

# loop over the newtext tokens (not the original!)
for i in range(len(newtext)-1):

  # create a pair
  pair = newtext[i] + newtext[i+1]

  # increase pair frequencies
  if pair in token_pairs:
    token_pairs[pair] += 1
  else:
    token_pairs[pair] = 1

token_pairs
# Out:
# {'li': 2,
#  'ik': 2,
#  'ke': 2,
#  'e ': 2,
#  ' l': 3,
#  'er': 1,
#  'r ': 1,
#  'lo': 2,
#  'ov': 2,
#  've': 2,
#  'el': 1,
#  'ly': 1,
#  'y h': 1,
#  ' hu': 3,
#  'ug': 3,
#  'g h': 2,
#  'gs': 1,
#  's h': 1,
#  'gg': 1,
#  'gi': 1,
#  'in': 1,
#  'ng': 1,
#  ' he': 1,
#  'ea': 1,
#  'ar': 1,
#  'rt': 1,
#  'ts': 1}

# %% [markdown]
# # Now using functions

# %%
# > -----------------------------------
def get_pair_stats(text2pair):
  token_pairs = dict()

  # loop over tokens
  for i in range(len(text2pair)-1):

    # create a pair
    pair = text2pair[i] + text2pair[i+1]

    # increase pair frequencies
    if pair in token_pairs:
      token_pairs[pair] += 1
    else:
      token_pairs[pair] = 1

  return token_pairs
# ----------------------------------- <



# > -----------------------------------
def update_vocab(token_pairs,vocab):

  # find the most frequent pair
  idx = np.argmax(list(token_pairs.values()))
  newtok = list(token_pairs.keys())[idx]

  # update the vocab
  vocab[newtok] = max(vocab.values())+1
  return vocab,newtok
# ----------------------------------- <



# -----------------------------------
def generate_new_token_seq(prevtext,newtoken):

  # initialize a new text list
  newtext = []

  # loop through the list
  i = 0
  while i<(len(prevtext)-1):

    # test whether the pair of this and the following elements match the newly-created pair
    if (prevtext[i]+prevtext[i+1]) == newtoken:
      newtext.append(newtoken)
      i += 2 # skip the next character

    # not a pair
    else:
      newtext.append(prevtext[i])
      i += 1 # move to the next character

  # add the final token to the list (missing in the video)
  if i < len(prevtext):
    newtext.append(prevtext[i])

  return newtext
# ----------------------------------- <

# %%
# re-initialize the vocab
vocab = { word:i for i,word in enumerate(chars) }
print(f'Vocab has {len(vocab)} tokens.')
# Out:
# Vocab has 16 tokens.

# %%
## do one iteration

# find and count pairs
pairs = get_pair_stats(origtext)

# update the dictionary
vocab,newtoken = update_vocab(pairs,vocab)

# get a new list of tokens
updated_text = generate_new_token_seq(origtext,newtoken)
print(f'Vocab has {len(vocab)} tokens.')
# Out:
# Vocab has 17 tokens.

# %%
updated_text
# Out:
# ['l',
#  'i',
#  'k',
#  'e',
#  ' ',
#  'l',
#  'i',
#  'k',
#  'e',
#  'r',
#  ' ',
#  'l',
#  'o',
#  'v',
#  'e',
#  ' ',
#  'l',
#  'o',
#  'v',
#  'e',
#  'l',
#  'y',
#  ' h',
#  'u',
#  'g',
#  ' h',
#  'u',
#  'g',
#  's',
#  ' h',
#  'u',
#  'g',
#  'g',
#  'i',
#  'n',
#  'g',
#  ' h',
#  'e',
#  'a',
#  'r',
#  't',
#  's']

# %%
## do a second iteration
pairs = get_pair_stats(updated_text)

# update the dictionary
vocab,newtoken = update_vocab(pairs,vocab)

# get a new list of tokens
updated_text = generate_new_token_seq(updated_text,newtoken)
print(f'Vocab has {len(vocab)} tokens.')
# Out:
# Vocab has 18 tokens.

# %%
vocab
# Out:
# {' ': 0,
#  'a': 1,
#  'e': 2,
#  'g': 3,
#  'h': 4,
#  'i': 5,
#  'k': 6,
#  'l': 7,
#  'n': 8,
#  'o': 9,
#  'r': 10,
#  's': 11,
#  't': 12,
#  'u': 13,
#  'v': 14,
#  'y': 15,
#  ' h': 16,
#  ' l': 17}

# %% [markdown]
# ## Use function to create 25 tokens

# %%
# re-initialize the vocab
vocab = { word:i for i,word in enumerate(chars) }
print(f'Vocab has {len(vocab)} tokens.')
# Out:
# Vocab has 16 tokens.

# %%
current_text = origtext.copy()
current_vocab = vocab.copy()

num_tokens = len(current_vocab)
k=0
while num_tokens < 25:
    print(f'\n\n--- Iteration {k} ---')
    pairs = get_pair_stats(current_text)
    current_vocab,newtoken = update_vocab(pairs,current_vocab)
    current_text = generate_new_token_seq(current_text,newtoken)
    num_tokens = len(current_vocab)
    print(f'Vocab has {num_tokens} tokens.')
    k += 1
# Out:
# --- Iteration 0 ---
# Vocab has 17 tokens.
#
#
# --- Iteration 1 ---
# Vocab has 18 tokens.
#
#
# --- Iteration 2 ---
# Vocab has 19 tokens.
#
#
# --- Iteration 3 ---
# Vocab has 20 tokens.
#
#
# --- Iteration 4 ---
# Vocab has 21 tokens.
#
#
# --- Iteration 5 ---
# Vocab has 22 tokens.
#
#
# --- Iteration 6 ---
# Vocab has 23 tokens.
#
#
# --- Iteration 7 ---
# Vocab has 24 tokens.
#
#
# --- Iteration 8 ---
# Vocab has 25 tokens.

# %%
current_text
# Out:
# ['l',
#  'ike',
#  ' l',
#  'ike',
#  'r',
#  ' love',
#  ' love',
#  'l',
#  'y',
#  ' hug',
#  ' hug',
#  's',
#  ' hug',
#  'g',
#  'i',
#  'n',
#  'g',
#  ' h',
#  'e',
#  'a',
#  'r',
#  't',
#  's']

# %%
current_vocab
# Out:
# {' ': 0,
#  'a': 1,
#  'e': 2,
#  'g': 3,
#  'h': 4,
#  'i': 5,
#  'k': 6,
#  'l': 7,
#  'n': 8,
#  'o': 9,
#  'r': 10,
#  's': 11,
#  't': 12,
#  'u': 13,
#  'v': 14,
#  'y': 15,
#  ' h': 16,
#  ' l': 17,
#  ' hu': 18,
#  ' hug': 19,
#  'ik': 20,
#  'ike': 21,
#  ' lo': 22,
#  ' lov': 23,
#  ' love': 24,
#  'like': 25,
#  'like l': 26,
#  'like like': 27,
#  'like liker': 28,
#  'like liker love': 29,
#  'like liker love love': 30,
#  'like liker love lovel': 31,
#  'like liker love lovely': 32,
#  'like liker love lovely hug': 33,
#  'like liker love lovely hug hug': 34,
#  'like liker love lovely hug hugs': 35,
#  'like liker love lovely hug hugs hug': 36,
#  'like liker love lovely hug hugs hugg': 37,
#  'like liker love lovely hug hugs huggi': 38,
#  'like liker love lovely hug hugs huggin': 39,
#  'like liker love lovely hug hugs hugging': 40,
#  'like liker love lovely hug hugs hugging h': 41,
#  'like liker love lovely hug hugs hugging he': 42,
#  'like liker love lovely hug hugs hugging hea': 43,
#  'like liker love lovely hug hugs hugging hear': 44,
#  'like liker love lovely hug hugs hugging heart': 45,
#  'like liker love lovely hug hugs hugging hearts': 46}
